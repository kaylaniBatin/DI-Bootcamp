# %% [markdown]
# <a href="https://colab.research.google.com/github/kaylaniBatin/DI-Bootcamp/blob/main/Week3Day2ExerciseXP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Exercise 1: Identifying Data Types
#
#
# 1.   A company’s financial reports stored in an Excel file. - structured data
# 2.   Photographs uploaded to a social media platform. - unstructured data
# 3. A collection of news articles on a website. - unstructured data
# 4. Inventory data in a relational database. - structured data
# 5. Recorded interviews from a market research study. - unstructured data

# %% [markdown]
# Exercise 2: Transformation Exercise
# 1.   A series of blog posts about travel experiences.
# Method: Use NLP to extract locations, dates, activities, and sentiments.
# Reason: Text analysis converts free-form writing into structured insights.
# 2.   Audio recordings of customer service calls.
# Method: Use speech-to-text, then NLP for topic and sentiment extraction.
# Reason: Transcription and analysis turn conversations into searchable data.
# 3. Handwritten notes from a brainstorming session.
# Method: Apply OCR to digitize text, then categorize content.
# Reason: Converts notes into editable, organized formats.
# 4. Video tutorial on cooking
# Method: Transcribe audio, segment steps, tag ingredients and actions.
# Reason: Creates a step-by-step recipe structure for easy reference.

# %% [markdown]
# Exercise 3: Import a file from Kaggle

# %%
import pandas as pd
df = pd.read_csv('train.zip')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# Exericse 4: Importing a CSV File

# %%
import pandas as pd
df = pd.read_csv('Iris_dataset.zip', names=['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'species'])
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %% [markdown]
# Exercise 5 : Export a dataframe to excel format and JSON format.

# %%
import pandas as pd

# %%
import pandas as pd

# Sample data
data = {
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Age': [25, 30, 35],
    'City': ['New York', 'London', 'Tokyo']
}

# Create DataFrame
df = pd.DataFrame(data)

# Display it
df
# Out:
#       Name  Age      City
# 0    Alice   25  New York
# 1      Bob   30    London
# 2  Charlie   35     Tokyo

# %%
# Install openpyxl for writing Excel .xlsx
# !pip install openpyxl

# Export to Excel .xlsx
df.to_excel("data_export.xlsx", index=False, engine='openpyxl')

# Download the Excel file
from google.colab import files
files.download("data_export.xlsx")

# %%
# Export to JSON
df.to_json("data_export.json", orient='records', indent=2)

# Download JSON
files.download("data_export.json")

# %% [markdown]
# Exercise 6: Reading JSON Data

# %%
import pandas as pd

url = "posts.zip"

df = pd.read_json(url)

df.head()
# Out:
#    userId  id                                              title  \
# 0       1   1  sunt aut facere repellat provident occaecati e...
# 1       1   2                                       qui est esse
# 2       1   3  ea molestias quasi exercitationem repellat qui...
# 3       1   4                               eum et est occaecati
# 4       1   5                                 nesciunt quas odio
#
#                                                 body
# 0  quia et suscipit\nsuscipit recusandae consequu...
# 1  est rerum tempore vitae\nsequi sint nihil repr...
# 2  et iusto sed quo iure\nvoluptatem occaecati om...
# 3  ullam et saepe reiciendis voluptatem adipisci\...
# 4  repudiandae veniam quaerat sunt sed\nalias aut...
